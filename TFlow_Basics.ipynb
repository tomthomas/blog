# %% [markdown]
# <a href="https://colab.research.google.com/github/tomthomas/blog/blob/master/TFlow_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
#Helper libs
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.4.0

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist

# %%
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# ...
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
class_names = [ 'T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Cost', 'Sandal','Shirt','Sneaker','Bag','Ankle boot']

# %%
train_images.shape
#60000 Images with each image as a 28 x 28 pixel
# Out:
# (60000, 28, 28)

# %%
len(train_labels)
#60000 labels in the training set
# Out:
# 60000

# %%
#each label is an integer between 0 and 9
train_labels
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
#test set shape
test_images.shape
#10000 images 28 x 28 pixels each
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %% [markdown]
# **Preprocessing**

# %%
plt.figure()    #create a figure
plt.imshow(train_images[0])    #creates image from 2D numpy array
plt.colorbar()  #creates a colorbar for pyplot
plt.grid(False) #dont show gridlines
plt.show()      #display figures

# %%
#scaling values from 0 to 1  i.e. divide by 255 
#Since pixel values fall between 0 and 255
#Both test and training set

train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
#Verify format
#Display first 25 images of training set

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1) #create subplot
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary) #cmap = colormap
    plt.xlabel(class_names[train_labels[i]])
plt.show()
